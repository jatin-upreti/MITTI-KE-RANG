# %%
import pandas as pd
import numpy as np

# %%
df=pd.read_csv('C:\\Users\Jatin Upreti\Downloads\MKRDATA_final.csv')
df
# Out:
#       Unnamed: 0            Timestamp  Age  Gender         Country  \
# 0              0  2014-08-27 11:29:31   37  Female   United States
# 1              1  2014-08-27 11:29:37   44       M   United States
# 2              2  2014-08-27 11:29:44   32    Male          Canada
# 3              3  2014-08-27 11:29:46   31    Male  United Kingdom
# 4              4  2014-08-27 11:30:22   31    Male   United States
# ...          ...                  ...  ...     ...             ...
# 1254        1254  2015-09-12 11:17:21   26    male  United Kingdom
# 1255        1255  2015-09-26 01:07:35   32    Male   United States
# 1256        1256  2015-11-07 12:36:58   34    male   United States
# 1257        1257  2015-11-30 21:25:06   46       f   United States
# 1258        1258  2016-02-01 23:04:31   25    Male   United States
#
#      self_employed family_history treatment    no_employees remote_work  ...  \
# 0               No             No       Yes            6-25          No  ...
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1259 entries, 0 to 1258
# Data columns (total 25 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   Unnamed: 0                 1259 non-null   int64
#  1   Timestamp                  1259 non-null   object
#  2   Age                        1259 non-null   int64
#  3   Gender                     1259 non-null   object
#  4   Country                    1259 non-null   object
#  5   self_employed              1259 non-null   object
#  6   family_history             1259 non-null   object
#  7   treatment                  1259 non-null   object
#  8   no_employees               1259 non-null   object
#  9   remote_work                1259 non-null   object
#  10  tech_company               1259 non-null   object
#  11  benefits                   1259 non-null   object
#  12  care_options               1259 non-null   object
# ...

# %%
df.columns
# Out:
# Index(['Unnamed: 0', 'Timestamp', 'Age', 'Gender', 'Country', 'self_employed',
#        'family_history', 'treatment', 'no_employees', 'remote_work',
#        'tech_company', 'benefits', 'care_options', 'wellness_program',
#        'seek_help', 'anonymity', 'leave', 'mental_health_consequence',
#        'phys_health_consequence', 'coworkers', 'supervisor',
#        'mental_health_interview', 'phys_health_interview',
#        'mental_vs_physical', 'obs_consequence'],
#       dtype='object')

# %%
df.shape
# Out:
# (1259, 25)

# %%
df.count()
# Out:
# Unnamed: 0                   1259
# Timestamp                    1259
# Age                          1259
# Gender                       1259
# Country                      1259
# self_employed                1259
# family_history               1259
# treatment                    1259
# no_employees                 1259
# remote_work                  1259
# tech_company                 1259
# benefits                     1259
# care_options                 1259
# wellness_program             1259
# seek_help                    1259
# anonymity                    1259
# leave                        1259
# mental_health_consequence    1259
# phys_health_consequence      1259
# coworkers                    1259
# supervisor                   1259
# mental_health_interview      1259
# phys_health_interview        1259
# mental_vs_physical           1259
# obs_consequence              1259
# dtype: int64

# %%
df.count(axis="columns")
# Out:
# 0       25
# 1       25
# 2       25
# 3       25
# 4       25
#         ..
# 1254    25
# 1255    25
# 1256    25
# 1257    25
# 1258    25
# Length: 1259, dtype: int64

# %%
df.describe(include='all')
# Out:
#          Unnamed: 0            Timestamp           Age Gender        Country  \
# count   1259.000000                 1259  1.259000e+03   1259           1259
# unique          NaN                 1246           NaN     49             48
# top             NaN  2014-08-27 12:31:41           NaN   Male  United States
# freq            NaN                    2           NaN    615            751
# mean     629.000000                  NaN  7.942815e+07    NaN            NaN
# std      363.586303                  NaN  2.818299e+09    NaN            NaN
# min        0.000000                  NaN -1.726000e+03    NaN            NaN
# 25%      314.500000                  NaN  2.700000e+01    NaN            NaN
# 50%      629.000000                  NaN  3.100000e+01    NaN            NaN
# 75%      943.500000                  NaN  3.600000e+01    NaN            NaN
# max     1258.000000                  NaN  1.000000e+11    NaN            NaN
#
# ...

# %%
df2=df.describe(include=['object'])

# %%
df2
# Out:
#                   Timestamp Gender        Country self_employed  \
# count                  1259   1259           1259          1259
# unique                 1246     49             48             2
# top     2014-08-27 12:31:41   Male  United States            No
# freq                      2    615            751          1113
#
#        family_history treatment no_employees remote_work tech_company  \
# count            1259      1259         1259        1259         1259
# unique              2         2            6           2            2
# top                No       Yes         6-25          No          Yes
# freq              767       637          290         883         1031
#
#        benefits  ...   anonymity       leave mental_health_consequence  \
# count      1259  ...        1259        1259                      1259
# unique        3  ...           3           5                         3
# top         Yes  ...  Don't know  Don't know                        No
# ...

# %%
df2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 4 entries, count to freq
# Data columns (total 23 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   Timestamp                  4 non-null      object
#  1   Gender                     4 non-null      object
#  2   Country                    4 non-null      object
#  3   self_employed              4 non-null      object
#  4   family_history             4 non-null      object
#  5   treatment                  4 non-null      object
#  6   no_employees               4 non-null      object
#  7   remote_work                4 non-null      object
#  8   tech_company               4 non-null      object
#  9   benefits                   4 non-null      object
#  10  care_options               4 non-null      object
#  11  wellness_program           4 non-null      object
#  12  seek_help                  4 non-null      object
# ...

# %%
df2.shape
# Out:
# (4, 23)
